# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Extracting features of 2022 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# /var/folders/33/syn88g8j53n7x_0ysjcp508w0000gn/T/ipykernel_78157/1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df.tail(30)
# Out:
#       Opening  Opening.1                                       Title  \
# 302  DECEMBER        1.0                       A Hollywood Christmas
# 303  DECEMBER        2.0                               Violent Night
# 304  DECEMBER        2.0                                Emancipation
# 305  DECEMBER        2.0                               Women Talking
# 306  DECEMBER        2.0                                     Marlowe
# 307  DECEMBER        2.0                               Spoiler Alert
# 308  DECEMBER        2.0         Diary of a Wimpy Kid: Rodrick Rules
# 309  DECEMBER        2.0                          Darby and the Dead
# 310  DECEMBER        2.0                     Lady Chatterley's Lover
# 311  DECEMBER        2.0                        The Eternal Daughter
# 312  DECEMBER        9.0                             Empire of Light
# 313  DECEMBER        9.0                         Matilda the Musical
# 314  DECEMBER        9.0  Night at the Museum: Kahmunrah Rises Again
# 315  DECEMBER        9.0                                   The Whale
# 316  DECEMBER        9.0                    Something from Tiffany's
# 317  DECEMBER        9.0                Detective Knight: Redemption
# 318  DECEMBER       12.0                               5000 Blankets
# 319  DECEMBER       16.0                    Avatar: The Way of Water
# 320  DECEMBER       21.0                Puss in Boots: The Last Wish
# 321  DECEMBER       21.0                 I Wanna Dance with Somebody
# 322  DECEMBER       21.0                                     Wildcat
# 323  DECEMBER       23.0                                     Babylon
# 324  DECEMBER       23.0                           The Pale Blue Eye
# 325  DECEMBER       25.0                           A Man Called Otto
# 326  DECEMBER       30.0                          They Cloned Tyrone
# 327  DECEMBER       30.0                              Alice, Darling
# 328  DECEMBER        NaN                                         NaN
# 329  DECEMBER        NaN                                         NaN
# 330  DECEMBER        NaN                                         NaN
# 331  DECEMBER        NaN                                         NaN
#
#                                     Production company  \
# 302                    HBO Max / Warner Bros. Pictures
# 303           Universal Pictures / 87North Productions
# 304  Apple TV+ / Apple Studios / Westbrook Studios ...
# 305              Orion Pictures / Plan B Entertainment
# 306                                    Open Road Films
# 307                                     Focus Features
# 308  Disney+ / Walt Disney Pictures / Bardel Entert...
# 309                        Hulu / 20th Century Studios
# 310                       Netflix / Blueprint Pictures
# 311                  A24 / BBC Film / Element Pictures
# 312     Searchlight Pictures / Neal Street Productions
# 313   Netflix / TriStar Pictures / Working Title Films
# 314  Disney+ / 20th Century Studios / 21 Laps Enter...
# 315                            A24 / Protozoa Pictures
# 316                    Amazon Studios / Hello Sunshine
# 317                                          Lionsgate
# 318                                   Affirm Originals
# 319    20th Century Studios / Lightstorm Entertainment
# 320          Universal Pictures / DreamWorks Animation
# 321               TriStar Pictures / Black Label Media
# 322                                     Amazon Studios
# 323                                 Paramount Pictures
# 324                     Netflix / Cross Creek Pictures
# 325  Columbia Pictures / Stage 6 Films / Playtone /...
# 326                                            Netflix
# 327                     Lionsgate / Elevation Pictures
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
#
#                                          Cast and crew  \
# 302  Alex Ranarivelo (director); John Ducey (screen...
# 303  Tommy Wirkola (director); Pat Casey, Josh Mill...
# 304  Antoine Fuqua (director); William N. Collage (...
# 305  Sarah Polley (director/screenplay); Rooney Mar...
# 306  Neil Jordan (director); William Monahan (scree...
# 307  Michael Showalter (director); David Marshall G...
# 308  Luke Cormican (director); Jeff Kinney (screenp...
# 309  Silas Howard (director); Wenonah Wilms, Becca ...
# 310  Laure de Clermont-Tonnerre (director); David M...
# 311   Joanna Hogg (director/screenplay); Tilda Swinton
# 312  Sam Mendes (director/screenplay); Olivia Colma...
# 313  Matthew Warchus (director); Dennis Kelly (scre...
# 314  Matt Danner (director); Ray DeLaurentis (scree...
# 315  Darren Aronofsky (director); Samuel D. Hunter ...
# 316  Daryl Wein (director); Tamara Chestna (screenp...
# 317  Edward John Drake (director/screenplay); Corey...
# 318  Amin Matalqa (director); Matthew Antonelli, La...
# 319  James Cameron (director/screenplay); Josh Frie...
# 320  Joel Crawford (director); Paul Fisher (screenp...
# 321  Kasi Lemmons (director); Anthony McCarten (scr...
# 322             Melissa Lesh, Trevor Frost (directors)
# 323  Damien Chazelle (director/screenplay); Brad Pi...
# 324  Scott Cooper (director/screenplay); Christian ...
# 325  Marc Forster (director), David Magee (screenpl...
# 326  Juel Taylor (director/screenplay); Tony Retten...
# 327  Mary Nighy (director); Alanna Francis (screenp...
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
# 307                                                NaN
# 308                                                NaN
# 309                                                NaN
# 310                                                NaN
# 311                                                NaN
# 312                                                NaN
# 313                                                NaN
# 314                                                NaN
# 315                                                NaN
# 316                                                NaN
# 317                                                NaN
# 318                                                NaN
# 319                                                NaN
# 320                                                NaN
# 321                                                NaN
# 322                                                NaN
# 323                                                NaN
# 324                                                NaN
# 325                                                NaN
# 326                                                NaN
# 327                                                NaN
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
#
#       Ref.
# 302  [240]
# 303  [251]
# 304  [252]
# 305  [253]
# 306  [254]
# 307  [255]
# 308  [256]
# 309    NaN
# 310  [220]
# 311    NaN
# 312  [257]
# 313  [183]
# 314  [258]
# 315  [259]
# 316  [179]
# 317  [260]
# 318    NaN
# 319  [261]
# 320  [262]
# 321   [55]
# 322  [179]
# 323  [263]
# 324  [183]
# 325  [264]
# 326  [220]
# 327  [265]
# 328    NaN
# 329    NaN
# 330    NaN
# 331    NaN

# %%
df_2022 = df[['Title','Cast and crew']]

# %%
df_2022
# Out:
#                         Title  \
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 327            Alice, Darling
# 328                       NaN
# 329                       NaN
# 330                       NaN
# 331                       NaN
#
#                                          Cast and crew
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 327  Mary Nighy (director); Alanna Francis (screenp...
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
#
# [332 rows x 2 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in /Users/merhawitsegay/opt/anaconda3/lib/python3.9/site-packages (1.7.7)
# Requirement already satisfied: requests in /Users/merhawitsegay/opt/anaconda3/lib/python3.9/site-packages (from tmdbv3api) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/merhawitsegay/opt/anaconda3/lib/python3.9/site-packages (from requests->tmdbv3api) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/merhawitsegay/opt/anaconda3/lib/python3.9/site-packages (from requests->tmdbv3api) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/merhawitsegay/opt/anaconda3/lib/python3.9/site-packages (from requests->tmdbv3api) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/merhawitsegay/opt/anaconda3/lib/python3.9/site-packages (from requests->tmdbv3api) (3.3)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'ddc46900c7ab22df7cb7c606418b5216'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))
# Out:
# /var/folders/33/syn88g8j53n7x_0ysjcp508w0000gn/T/ipykernel_78157/2369738557.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2022
# Out:
#                         Title  \
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 327            Alice, Darling
# 328                       NaN
# 329                       NaN
# 330                       NaN
# 331                       NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 327  Mary Nighy (director); Alanna Francis (screenp...
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
#
#                           genres
# 0                Action Thriller
# 1       Family Animation Fantasy
# 2          Action Crime Thriller
# 3    Action Thriller Crime Drama
# 4        Horror Mystery Thriller
# ..                           ...
# 327               Thriller Drama
# 328                          NaN
# 329                          NaN
# 330                          NaN
# 331                          NaN
#
# [332 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# /var/folders/33/syn88g8j53n7x_0ysjcp508w0000gn/T/ipykernel_78157/3796821595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# /var/folders/33/syn88g8j53n7x_0ysjcp508w0000gn/T/ipykernel_78157/2929607607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# /var/folders/33/syn88g8j53n7x_0ysjcp508w0000gn/T/ipykernel_78157/2384233428.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2022
# Out:
#                         Title  \
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 327            Alice, Darling
# 328                       NaN
# 329                       NaN
# 330                       NaN
# 331                       NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 327  Mary Nighy (director); Alanna Francis (screenp...
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
#
#                           genres                         director_name  \
# 0                Action Thriller                         Simon Kinberg
# 1       Family Animation Fantasy                Patricia Harris Seeley
# 2          Action Crime Thriller                            Asif Akbar
# 3    Action Thriller Crime Drama                          Edward Drake
# 4        Horror Mystery Thriller  Matt Bettinelli-Olpin, Tyler Gillett
# ..                           ...                                   ...
# 327               Thriller Drama                            Mary Nighy
# 328                          NaN                                   nan
# 329                          NaN                                   nan
# 330                          NaN                                   nan
# 331                          NaN                                   nan
#
#           actor_1_name       actor_2_name     actor_3_name
# 0     Jessica Chastain     Lupita Nyong'o    Penélope Cruz
# 1        Autumn Reeser       Antonio Cupo      Danny Trejo
# 2        Mickey Rourke  Michael Jai White              NaN
# 3    Timothy V. Murphy       Bruce Willis              NaN
# 4      Melissa Barrera      Mason Gooding     Jenna Ortega
# ..                 ...                ...              ...
# 327      Anna Kendrick    Kaniehtiio Horn  Charlie Carrick
# 328                nan                NaN              NaN
# 329                nan                NaN              NaN
# 330                nan                NaN              NaN
# 331                nan                NaN              NaN
#
# [332 rows x 7 columns]

# %%
df_2022 = df_2022.rename(columns={'Title':'movie_title'})

# %%
new_df22 = df_2022.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df22
# Out:
#                             director_name       actor_1_name  \
# 0                           Simon Kinberg   Jessica Chastain
# 1                  Patricia Harris Seeley      Autumn Reeser
# 2                              Asif Akbar      Mickey Rourke
# 3                            Edward Drake  Timothy V. Murphy
# 4    Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera
# ..                                    ...                ...
# 327                            Mary Nighy      Anna Kendrick
# 328                                   nan                nan
# 329                                   nan                nan
# 330                                   nan                nan
# 331                                   nan                nan
#
#           actor_2_name     actor_3_name                       genres  \
# 0       Lupita Nyong'o    Penélope Cruz              Action Thriller
# 1         Antonio Cupo      Danny Trejo     Family Animation Fantasy
# 2    Michael Jai White              NaN        Action Crime Thriller
# 3         Bruce Willis              NaN  Action Thriller Crime Drama
# 4        Mason Gooding     Jenna Ortega      Horror Mystery Thriller
# ..                 ...              ...                          ...
# 327    Kaniehtiio Horn  Charlie Carrick               Thriller Drama
# 328                NaN              NaN                          NaN
# 329                NaN              NaN                          NaN
# 330                NaN              NaN                          NaN
# 331                NaN              NaN                          NaN
#
#                   movie_title
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 327            Alice, Darling
# 328                       NaN
# 329                       NaN
# 330                       NaN
# 331                       NaN
#
# [332 rows x 6 columns]

# %%
new_df22['comb'] = new_df22['actor_1_name'] + ' ' + new_df22['actor_2_name'] + ' '+ new_df22['actor_3_name'] + ' '+ new_df22['director_name'] +' ' + new_df22['genres']

# %%
new_df22.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name     11
# actor_3_name     38
# genres            5
# movie_title       4
# comb             39
# dtype: int64

# %%
new_df22 = new_df22.dropna(how='any')

# %%
new_df22.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df22['movie_title'] = new_df22['movie_title'].str.lower()
# Out:
# /var/folders/33/syn88g8j53n7x_0ysjcp508w0000gn/T/ipykernel_78157/2732328091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df22['movie_title'] = new_df22['movie_title'].str.lower()

# %%
new_df22
# Out:
#                             director_name      actor_1_name     actor_2_name  \
# 0                           Simon Kinberg  Jessica Chastain   Lupita Nyong'o
# 1                  Patricia Harris Seeley     Autumn Reeser     Antonio Cupo
# 4    Matt Bettinelli-Olpin, Tyler Gillett   Melissa Barrera    Mason Gooding
# 5           Jennifer Kluska, Derek Drymon      Andy Samberg     Selena Gomez
# 6                             Luis Prieto  Cameron Monaghan     Frank Grillo
# ..                                    ...               ...              ...
# 323                       Damien Chazelle         Brad Pitt    Margot Robbie
# 324                          Scott Cooper    Christian Bale    Harry Melling
# 325                          Marc Forster         Tom Hanks  Mariana Treviño
# 326                           Juel Taylor       John Boyega   Teyonah Parris
# 327                            Mary Nighy     Anna Kendrick  Kaniehtiio Horn
#
#           actor_3_name                                     genres  \
# 0        Penélope Cruz                            Action Thriller
# 1          Danny Trejo                   Family Animation Fantasy
# 4         Jenna Ortega                    Horror Mystery Thriller
# 5         Kathryn Hahn  Animation Comedy Family Fantasy Adventure
# 6           Lilly Krug                                   Thriller
# ..                 ...                                        ...
# 323        Diego Calva                               Drama Comedy
# 324   Gillian Anderson              Crime Thriller Mystery Horror
# 325      Rachel Keller                               Drama Comedy
# 326  Kiefer Sutherland             Science Fiction Comedy Mystery
# 327    Charlie Carrick                             Thriller Drama
#
#                            movie_title  \
# 0                              the 355
# 1             the legend of la llorona
# 4                               scream
# 5    hotel transylvania: transformania
# 6                            shattered
# ..                                 ...
# 323                            babylon
# 324                  the pale blue eye
# 325                  a man called otto
# 326                 they cloned tyrone
# 327                     alice, darling
#
#                                                   comb
# 0    Jessica Chastain Lupita Nyong'o Penélope Cruz ...
# 1    Autumn Reeser Antonio Cupo Danny Trejo Patrici...
# 4    Melissa Barrera Mason Gooding Jenna Ortega Mat...
# 5    Andy Samberg Selena Gomez Kathryn Hahn Jennife...
# 6    Cameron Monaghan Frank Grillo Lilly Krug Luis ...
# ..                                                 ...
# 323  Brad Pitt Margot Robbie Diego Calva Damien Cha...
# 324  Christian Bale Harry Melling Gillian Anderson ...
# 325  Tom Hanks Mariana Treviño Rachel Keller Marc F...
# 326  John Boyega Teyonah Parris Kiefer Sutherland J...
# 327  Anna Kendrick Kaniehtiio Horn Charlie Carrick ...
#
# [293 rows x 7 columns]

# %%
old_df = pd.read_csv('/Users/merhawitsegay/Downloads/self_study/github/ds_ml_02/final_data.csv')

# %%
old_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5875  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5876            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5877              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5878   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5879         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  unknown                               Documentary
# ...                    ...                                       ...
# 5875         Rashida Jones  Animation Action Adventure Comedy Family
# 5876         Florence Pugh                     Drama Romance History
# 5877           Mark Strong                  War Drama Action History
# 5878           Brie Larson                       Drama Crime History
# 5879           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5875                                  spies in disguise
# 5876                                       little women
# 5877                                               1917
# 5878                                         just mercy
# 5879                                           clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5875  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5876  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5877  George MacKay Dean-Charles Chapman Mark Strong...
# 5878  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5879  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5880 rows x 7 columns]

# %%
final_df = old_df.append(new_df22,ignore_index=True)
# Out:
# /var/folders/33/syn88g8j53n7x_0ysjcp508w0000gn/T/ipykernel_78157/1166909226.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(new_df22,ignore_index=True)

# %%
final_df
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6168    Damien Chazelle        Brad Pitt     Margot Robbie
# 6169       Scott Cooper   Christian Bale     Harry Melling
# 6170       Marc Forster        Tom Hanks   Mariana Treviño
# 6171        Juel Taylor      John Boyega    Teyonah Parris
# 6172         Mary Nighy    Anna Kendrick   Kaniehtiio Horn
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 6168           Diego Calva                     Drama Comedy
# 6169      Gillian Anderson    Crime Thriller Mystery Horror
# 6170         Rachel Keller                     Drama Comedy
# 6171     Kiefer Sutherland   Science Fiction Comedy Mystery
# 6172       Charlie Carrick                   Thriller Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6168                                            babylon
# 6169                                  the pale blue eye
# 6170                                  a man called otto
# 6171                                 they cloned tyrone
# 6172                                     alice, darling
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6168  Brad Pitt Margot Robbie Diego Calva Damien Cha...
# 6169  Christian Bale Harry Melling Gillian Anderson ...
# 6170  Tom Hanks Mariana Treviño Rachel Keller Marc F...
# 6171  John Boyega Teyonah Parris Kiefer Sutherland J...
# 6172  Anna Kendrick Kaniehtiio Horn Charlie Carrick ...
#
# [6173 rows x 7 columns]

# %%
main_data2 = pd.read_csv('/Users/merhawitsegay/Downloads/self_study/github/ds_ml_02/main_data.csv')

# %%
main_data2 =pd.concat([final_df,main_data],ignore_index=True)

# %%
main_data2.tail()
# Out:
#           director_name           actor_1_name  actor_2_name   actor_3_name  \
# 12293       Pete Docter             Jamie Foxx      Tina Fey  Graham Norton
# 12294  Robert Rodriguez  Priyanka Chopra Jonas  Pedro Pascal  YaYa Gosselin
# 12295       Regina King      Kingsley Ben-Adir     Eli Goree    Aldis Hodge
# 12296   Emerald Fennell         Carey Mulligan    Bo Burnham    Alison Brie
# 12297  Kornél Mundruczó          Vanessa Kirby  Shia LaBeouf   Molly Parker
#
#                                       genres            movie_title  \
# 12293  Animation Family Comedy Fantasy Drama                   soul
# 12294           Action Fantasy Family Comedy       we can be heroes
# 12295                                  Drama  one night in miami...
# 12296                   Thriller Crime Drama  promising young woman
# 12297                                  Drama      pieces of a woman
#
#                                                     comb
# 12293  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 12294  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 12295  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 12296  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 12297  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...

# %%
main_data2.to_csv('main_data.csv',index=False)

# %%
main_data
